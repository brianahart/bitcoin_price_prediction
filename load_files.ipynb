# %% [markdown]
# Load Files

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9adf64c7-ac37-4832-94c8-76af715f0aec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9adf64c7-ac37-4832-94c8-76af715f0aec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"brianahart","key":"7b3d14b7ea9c8c10990fb0027bb03dfe"}'}

# %%
#! pip install -q kaggle
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list
# Out:
# ref                                                             title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# victorsoeiro/netflix-tv-shows-and-movies                        Netflix TV Shows and Movies                           2MB  2022-05-15 00:01:23          10266        312  1.0
# devansodariya/student-performance-data                          Student Performance Dataset                           7KB  2022-05-26 13:55:09           5699        177  0.9705882
# mohamedharris/supermart-grocery-sales-retail-analytics-dataset  Supermart Grocery Sales - Retail Analytics Dataset  191KB  2022-06-12 16:14:44            840         44  0.88235295
# sameepvani/nasa-nearest-earth-objects                           NASA - Nearest Earth Objects                          7MB  2022-06-17 02:32:18            560         41  1.0
# ruchi798/data-science-job-salaries                              Data Science Job Salaries                             7KB  2022-06-15 08:59:12           1014         49  1.0
# iamsouravbanerjee/software-professional-salaries-2022           Salary Dataset - 2022                               526KB  2022-06-15 17:13:05           2042         54  1.0
# hanzlanawaz/monkeypox-outbreak                                  Monkeypox Outbreak Dataset                           27KB  2022-06-06 03:13:58            874         43  0.9705882
# mayureshkoli/police-deaths-in-usa-from-1791-to-2022             Police deaths in USA from 1791 to 2022              698KB  2022-06-09 17:47:57           1017         32  1.0
# imoore/age-dataset                                              Age dataset: life, work, and death of 1.22M people   34MB  2022-06-07 08:56:52            909         57  1.0
# hassanshehzadk/top-50-most-followed-instagram-accounts          Top 50 Most Followed Instagram Accounts               2KB  2022-06-07 06:40:27            476         26  1.0
# paradisejoy/top-hits-spotify-from-20002019                      Top Hits Spotify from 2000-2019                      94KB  2022-05-31 07:20:57           7445        168  1.0
# saddamazyazy/go-to-college-dataset                              Go To College Dataset                                12KB  2022-05-20 10:46:02           2190         54  1.0
# outofskills/driving-behavior                                    Driving Behavior                                    196KB  2022-06-05 09:40:48            524         33  1.0
# odins0n/amex-parquet                                            Amex Competition Data in Parquet Format               9GB  2022-05-25 23:20:19           1055        132  1.0
# dansbecker/melbourne-housing-snapshot                           Melbourne Housing Snapshot                          451KB  2018-06-05 12:52:24          89424       1097  0.7058824
# digvijaysinhgohil/imdb-dataset-toprated-films-18982022          IMDb Dataset Top-Rated films 1898-2022               50KB  2022-06-15 08:41:14            401         31  1.0
# srivnaman/data-science-and-ai-jobs-indeed                       Data Science and AI Jobs Indeed                      59KB  2022-06-16 16:40:52            232         28  0.88235295
# surajjha101/stores-area-and-sales-data                          Supermarket store branches sales analysis            10KB  2022-04-29 11:10:16           7349        198  1.0
# ruchi798/parquet-files-amexdefault-prediction                   Feather & Parquet Files : AMEX-Default Prediction    22GB  2022-05-26 05:46:53            767        110  1.0
# azminetoushikwasi/ucl-202122-uefa-champions-league              UCL ⚽ 2021-22 ⭐ Players Data | Champions League      55KB  2022-06-20 03:01:18           1809         58  1.0

# %%
! kaggle datasets download -d kognitron/zielaks-bitcoin-historical-data-wo-nan
! kaggle datasets download -d mczielinski/bitcoin-historical-data
# Out:
# Downloading zielaks-bitcoin-historical-data-wo-nan.zip to /content
#  87% 85.0M/97.8M [00:00<00:00, 138MB/s]
# 100% 97.8M/97.8M [00:00<00:00, 129MB/s]
# Downloading bitcoin-historical-data.zip to /content
#  83% 83.0M/100M [00:00<00:00, 184MB/s]
# 100% 100M/100M [00:00<00:00, 171MB/s]

# %%
! ls
# Out:
# bitcoin-historical-data.zip  zielaks-bitcoin-historical-data-wo-nan.zip
# sample_data

# %%
! unzip bitcoin-historical-data.zip
# Out:
# Archive:  bitcoin-historical-data.zip
#   inflating: bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv

# %%
! unzip zielaks-bitcoin-historical-data-wo-nan.zip
# Out:
# Archive:  zielaks-bitcoin-historical-data-wo-nan.zip
#   inflating: bitstamp_cleaned.csv
